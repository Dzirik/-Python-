# %% [markdown]
# # Různé grafy

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Vyplněný kus grafu

# %%
df = pd.DataFrame(np.random.rand(10,3), columns=["n_limit_s", "a", "b"])
df["n_limit_s"] = list(range(1,df.shape[0]+1))
df["a"] = 10 * df["a"]
df
# Out:
#    n_limit_s         a         b
# 0          1  0.816703  0.938647
# 1          2  7.465358  0.013744
# 2          3  3.233223  0.090285
# 3          4  6.359815  0.483259
# 4          5  7.265789  0.500847
# 5          6  0.753806  0.715454
# 6          7  3.443535  0.351033
# 7          8  4.247688  0.142742
# 8          9  4.217918  0.405173
# 9         10  2.906277  0.596688

# %%
what_is_plotting = "Score"
offer_id = "12"

fig = plt.figure()
ax = plt.subplot(111)

x_axis = 1
for col in df.columns:
    if col != "n_limit_s":
        ax.plot(df["n_limit_s"], df[col], 
                label=col, marker="o")

#box
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#finishing plot
if what_is_plotting == "Score":
    plt.axhspan(0, 0.5, facecolor="yellow", alpha=0.3)
    plt.axhspan(0.5, 1, facecolor="orange", alpha=0.3)
    #ax.plot(df["n_limit_s"], [0] * df.shape[0], ls="dashed", c="black", lw=3) #just line at 0
#plt.axvspan(0, 1, facecolor="yellow", alpha=0.3)
plt.title(what_is_plotting + " for offer " + offer_id)
plt.xlabel("Max Number of Observations")
plt.ylabel(what_is_plotting)
plt.show()

# %% [markdown]
# ## Error Bars
#
# [info](https://stackoverflow.com/questions/12957582/matplotlib-plot-yerr-xerr-as-shaded-region-rather-than-error-bars)

# %%
df = pd.DataFrame(np.random.rand(10,3), columns=["n_limit_s", "mean", "std"])
df = df.sort_values(by="mean")
df["n_limit_s"] = list(range(1,df.shape[0]+1))
df["std"] = df["mean"] / 10
df
# Out:
#    n_limit_s      mean       std
# 2          1  0.268548  0.026855
# 4          2  0.280718  0.028072
# 1          3  0.288522  0.028852
# 3          4  0.336700  0.033670
# 7          5  0.339888  0.033989
# 8          6  0.452226  0.045223
# 5          7  0.520556  0.052056
# 9          8  0.562633  0.056263
# 0          9  0.683776  0.068378
# 6         10  0.987456  0.098746

# %%
x = df["n_limit_s"]
y = df["mean"]
error = df["std"]
title = "ahoj 123"

plt.plot(x, y, 'k', color="black")
plt.fill_between(x, y-error, y+error,
    alpha=0.5, edgecolor='#CC4F1B', facecolor='#FF9848')
plt.title(title)
plt.xlabel("Number of Observations")
plt.ylabel("Score")
plt.ylim([-0.4, 1.4])
plt.show()

# %%
import sys
sys.path.insert(0,"K:\\=Repos=\\vykonia.ai.model_1\\") 
sys.path.insert(0,"K:\\=Repos=\\george1.0\\")
