# %% [markdown]
# # Zdroje
#
# Udemy - Python for Data Science and Machine Learning Bootcamp (Jose Portia)
#
# Web:
#
# * [oficiální web](http://matplotlib.org/)
#     * [gallery](http://matplotlib.org/gallery.html)
#     * [api](http://matplotlib.org/api/)
#
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.

# %% [markdown]
# # Instalace

# %%
#conda install matplotlib
#pip install matplotlib

# %% [markdown]
# # Základy

# %%
#zobrazení v notebooku
#%matplotlib inline
# %matplotlib notebook

# %%
#import knihovny
import matplotlib.pyplot as plt
import matplotlib

# %%
import numpy as np

x=np.linspace(0,5,11)
y=x**2

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %% [markdown]
# ### Function Method

# %%
plt.plot(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Title")
#plt.show() když nejsem v jupyteru - printing, místo %matplotlib inline
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# subplot
#
# * počet řad
# * počet slupců
# * číslo

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r-")

plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %% [markdown]
# ### OOP Method

# %%
#vytvořím objekt
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,...">

# %%
axes=fig.add_axes([0.1,0.1,0.8,0.8]) # left, bottom, width, height (range 0 to 1)

# %%
axes.plot(x,y)
axes.set_xlabel("X label")
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')

# %%
fig
# Out:
# <img src="data:image/png;base64,...">

# %%
fig=plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### subplot()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)
plt.tight_layout() #kvůli překrývání se
# Out:
# <img src="data:image/png;base64,...">

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2FDA4E4A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2FDA9E208>], dtype=object)

# %%
for current_ax in axes:
    current_ax.plot(x,y)

# %%
axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

plt.tight_layout() #kvůli překrývání se

# %% [markdown]
# ## Figure size and DPI

# %%
fig=plt.figure(figsize=(8,2))

ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, axes = plt.subplots(nrows=2,ncols=1,dpi=100,figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Save Figure

# %%
fig.savefig("my_picture.png",dpi=200)

# %%
pwd()
# Out:
# 'R:\\-Python-\\G - Matplotlib'

# %% [markdown]
# ### Legends
#
# [url](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.legend)

# %%
fig= plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,x**2,label="x squared")
ax.plot(x,x**3,label="x cubed")

ax.legend(loc=(0.1,0.1))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Colors

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y,color="#DB9501")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Line width

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y,color="#DB9501",linewidth=3)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y,color="#DB9501",linewidth=3,alpha=0.5)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### line types

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y,color="#DB9501",linestyle="-.")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Markers

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y,marker="*",markersize=30,markerfacecolor="yellow", markeredgewidth=2,markeredgecolor="green")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Axis apperance

# %%
fig = plt.figure()

ax=fig.add_axes([0.2,0.2,0.8,0.8])
ax.plot(x,y)

ax.set_xlim([0,3])
ax.set_ylim([0,10])
# Out:
# <img src="data:image/png;base64,...">
# (0, 10)

# %% [markdown]
# ## Special plots

# %%
import matplotlib.pyplot as plt
from numpy.random import rand


fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = rand(2, n)
    scale = 200.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
plt.scatter(x,y)

# %%
"""
Simple demo of a scatter plot.
"""
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
